# %%
import sys
sys.path.append('../src')
from EEG_loader import load_eeg_dataset

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
Path('../figures').mkdir(exist_ok=True)

# %%
df, raws = load_eeg_dataset(
    edf_dir='../Kural_Dataset/Recordings',
    demographics_csv='../Kural_Dataset/Demographics.csv'
)
#df

# %%
print(f"Files loaded: {len(raws)} out of {len(df)}")
print(df['load_error'].value_counts(dropna=False))

# check annotation status
df['annotation_status'].value_counts()
# Out:
# Files loaded: 100 out of 100
# load_error
# None    100
# Name: count, dtype: int64
# annotation_status
# ok    100
# Name: count, dtype: int64

# %%
# check frequency sampling rates
df['sfreq_hz'].value_counts()

# frequency sampling rate discrepancy with paper
# Out:
# sfreq_hz
# 500.0    100
# Name: count, dtype: int64

# %%
# check number of EEG channels per participant

df['n_channels_total'].value_counts()
df['n_eeg_channels'].value_counts()
# Out:
# n_eeg_channels
# 25    97
# 19     3
# Name: count, dtype: int64

# %%
# which files have 19 channels
odd_files = df[df['n_eeg_channels'] == 19]['file_id'].tolist()
print("Files with 19 EEG channels:", odd_files)
print(df[df['file_id'].isin(odd_files)][['file_id', 'label', 'age', 'gender']])
# Out:
# Files with 19 EEG channels: ['S33', 'S65', 'S96']
#    file_id      label  age gender
# 33     S33  Epileptic    2      F
# 65     S65  Epileptic   41      F
# 96     S96  Epileptic   14      F

# %%
# compare channel names
normal_file = df[df['n_eeg_channels'] == 25]['file_id'].iloc[0]
odd_file = odd_files[0]

normal_chs = set(raws[normal_file].ch_names)
odd_chs = set(raws[odd_file].ch_names)

print("Channels in normal file but missing from odd file:")
print(normal_chs - odd_chs)

print("\nChannels in odd file but not in normal file:")
print(odd_chs - normal_chs)
# Out:
# Channels in normal file but missing from odd file:
# {'E T10-Ref', 'E T9-Ref', 'E P10-Ref', 'E F9-Ref', 'E P9-Ref', 'E F10-Ref'}
#
# Channels in odd file but not in normal file:
# set()

# %%
# add reduced channel column to df
df['reduced_channels'] = df['n_eeg_channels'] == 19
#df

# %% [markdown]
# ## Transient Properties

# %%
# summary stats per group
cols = ['duration_s', 'transient_onset_s', 'pre_transient_s', 'post_transient_s', 'frac_position']

summary = df.groupby('label')[cols].describe().T
summary
# Out:
# label                    Epileptic  Non_Epileptic
# duration_s        count  54.000000      46.000000
#                   mean   12.794296      12.432783
#                   std     0.490653       0.860289
#                   min    11.998000      10.998000
#                   25%    12.998000      11.998000
#                   50%    12.998000      12.998000
#                   75%    12.998000      12.998000
#                   max    13.998000      12.998000
# transient_onset_s count  54.000000      46.000000
#                   mean    6.318476       6.144613
#                   std     0.632843       0.511044
#                   min     2.330100       5.076900
#                   25%     6.147025       5.905850
#                   50%     6.432750       6.222100
#                   75%     6.617100       6.527800
#                   max     7.004300       6.875000
# pre_transient_s   count  54.000000      46.000000
#                   mean    6.318476       6.144613
# ...

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 8))
axes = axes.flatten()

for i, col in enumerate(cols):
    for label, group in df.groupby('label'):
        axes[i].hist(group[col], bins=15, alpha=0.5, label=label)
    axes[i].set_title(col)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('count')
    axes[i].legend()

axes[-1].axis('off')  # unused subplot
plt.tight_layout()
plt.savefig('../figures/transient_properties_hist.png', dpi=800, bbox_inches='tight')
plt.show()

# %%
fig, axes = plt.subplots(1, len(cols), figsize=(18, 4))

for i, col in enumerate(cols):
    df.boxplot(column=col, by='label', ax=axes[i])
    axes[i].set_title(col)
    axes[i].set_xlabel('')

plt.tight_layout()
plt.savefig('../figures/transient_properties_box.png', dpi=800, bbox_inches='tight')
plt.show()

# %%
# epochs where the transient is very close to the start or end
edge_cases = df[(df['frac_position'] < 0.2) | (df['frac_position'] > 0.8)]
print("Transients near epoch edges:")
print(edge_cases[['file_id', 'label', 'pre_transient_s', 'post_transient_s', 'duration_s', 'frac_position']])
# Out:
# Transients near epoch edges:
#    file_id      label  pre_transient_s  post_transient_s  duration_s  \
# 82     S82  Epileptic           2.3301           10.6679      12.998
#
#     frac_position
# 82         0.1793

# %%
raw = raws['S82']
print(raw.annotations.onset)
print(raw.annotations.description)
print(raw.times[-1])
# Out:
# [0.       2.330101]
# ['Marker: Review Progress' 'Marker: Annotation']
# 12.998

# %%
# extra annotataions in the EDF files
hawk = df[df['all_annotation_labels'].str.contains('Hawk_Cmd_Log')]
print(f"Files with Hawk_Cmd_Log: {len(hawk)}")
print(hawk[['file_id', 'label']])
# Out:
# Files with Hawk_Cmd_Log: 11
#    file_id          label
# 19     S19      Epileptic
# 20     S20  Non_Epileptic
# 42     S42      Epileptic
# 44     S44      Epileptic
# 45     S45      Epileptic
# 48     S48  Non_Epileptic
# 61     S61  Non_Epileptic
# 66     S66  Non_Epileptic
# 73     S73  Non_Epileptic
# 89     S89  Non_Epileptic
# 94     S94      Epileptic

# %%
df['has_hawk_log'] = df['all_annotation_labels'].str.contains('Hawk_Cmd_Log')

# %% [markdown]
# ## Metadata EDA

# %%
print(df['label'].value_counts())
# Out:
# label
# Epileptic        54
# Non_Epileptic    46
# Name: count, dtype: int64

# %%
print(df['gender'].value_counts())
print()
print(df.groupby('label')['gender'].value_counts())
# Out:
# gender
# F    60
# M    40
# Name: count, dtype: int64
#
# label          gender
# Epileptic      M         29
#                F         25
# Non_Epileptic  F         35
#                M         11
# Name: count, dtype: int64

# %%
# age properties
df.groupby('label')['age'].describe()
# Out:
#                count       mean        std   min    25%   50%    75%   max
# label
# Epileptic       54.0  32.481481  18.886694   2.0  19.50  29.0  43.25  77.0
# Non_Epileptic   46.0  37.608696  19.671161  11.0  20.25  34.5  52.75  89.0

# %%
fig, ax = plt.subplots(figsize=(6, 4))

df.boxplot(column='age', by='label', ax=ax)
ax.set_title('Age distribution by group')
ax.set_xlabel('')
ax.set_ylabel('Age')
plt.suptitle('')
plt.tight_layout()
plt.savefig('../figures/age_by_group.png', dpi=800, bbox_inches='tight')
plt.show()

# %%
# missing values
df.isnull().sum()
# Out:
# file_id                    0
# sample_id                  0
# label                      0
# label_binary               0
# gender                     0
# age                        0
# sfreq_hz                   0
# duration_s                 0
# n_channels_total           0
# n_eeg_channels             0
# n_annotations_total        0
# n_transient_markers        0
# annotation_status          0
# transient_onset_s          0
# pre_transient_s            0
# post_transient_s           0
# frac_position              0
# all_annotation_labels      0
# load_error               100
# reduced_channels           0
# has_hawk_log               0
# dtype: int64

# %% [markdown]
# # signal level EDA

# %% [markdown]
# ## Transient amplitude

# %%
# define peri-transient window in seconds
pre_ms = 0.1   # 100ms before marker
post_ms = 0.1  # 100ms after marker

# get the channel names from any full file (excluding EKG)
reference_file = 'S01'
eeg_ch_names = [ch for ch in raws[reference_file].ch_names if 'EKG' not in ch]

# store results
peak_amp_records = []

for file_id, raw in raws.items():
    sfreq = raw.info['sfreq']
    
    # get transient onset time
    transient_anns = [a for a in raw.annotations if 'Annotation' in a['description']]
    if len(transient_anns) != 1:
        continue
    t_onset = transient_anns[0]['onset']
    
    # define window sample indices
    samp_start = int((t_onset - pre_ms) * sfreq)
    samp_end   = int((t_onset + post_ms) * sfreq)
    
    # get EEG channels only
    eeg_chs = [ch for ch in raw.ch_names if 'EKG' not in ch]
    eeg_idx  = [raw.ch_names.index(ch) for ch in eeg_chs]
    
    # extract window
    data, _ = raw[eeg_idx, samp_start:samp_end]  # shape: (n_channels, n_samples)
    data_uv  = data * 1e6  # convert to microvolts
    
    # peak absolute amplitude per channel
    peak_per_channel = np.abs(data_uv).max(axis=1)  # shape: (n_channels,)
    
    record = {'file_id': file_id}
    for ch_name, peak in zip(eeg_chs, peak_per_channel):
        record[ch_name] = round(peak, 4)
    
    peak_amp_records.append(record)

# build dataframe: rows = files, columns = channels
peak_amp_df = pd.DataFrame(peak_amp_records).set_index('file_id')
peak_amp_df = peak_amp_df.sort_index()

print(f"Shape: {peak_amp_df.shape}")
print(peak_amp_df.head())
# Out:
# Shape: (100, 25)
#          E FP1-Ref  E FP2-Ref  E F3-Ref  E F4-Ref  E C3-Ref  E C4-Ref  \
# file_id
# S01        16.9953    25.0049   17.0011   40.9995   18.9998   80.0006
# S02        35.6518    43.8993   21.6684   19.3254   11.3501   11.2218
# S03        64.9930    76.9883   76.9883  120.9815   37.9966   39.0044
# S04        45.9979    34.9934   34.9937   27.0034   43.9939   13.9998
# S05        82.9906    86.9793   60.9907   50.9938   28.0015   40.9953
#
#          E P3-Ref  E P4-Ref  E O1-Ref  E O2-Ref  ...  E P8-Ref  E P9-Ref  \
# file_id                                          ...
# S01       20.0001   18.0009   18.0006   26.9997  ...   13.9927   26.0016
# S02       11.5414   19.5887   29.4629   41.8983  ...   58.5778   43.2774
# S03       35.0002   16.9971   62.9981   54.0049  ...   43.9987   70.9892
# S04       29.9927   13.9986   39.0036   32.0009  ...   37.0034   45.0028
# S05       31.0023   32.9973   37.9988   36.9969  ...   50.9984   55.9983
#
# ...

# %%
# merge with labels
peak_amp_df['label'] = peak_amp_df.index.map(df.set_index('file_id')['label'])

# global peak: single highest amplitude across all channels
peak_amp_df['global_peak_uv'] = peak_amp_df[eeg_ch_names].max(axis=1)

# mean peak: average peak amplitude across all channels
peak_amp_df['mean_peak_uv'] = peak_amp_df[eeg_ch_names].mean(axis=1)

# dominant channel: which channel had the highest peak
peak_amp_df['dominant_channel'] = peak_amp_df[eeg_ch_names].idxmax(axis=1)

# focality ratio: global peak / mean peak
# high value = transient is focal (one channel much larger than others)
# low value  = transient is spatially widespread
peak_amp_df['focality_ratio'] = peak_amp_df['global_peak_uv'] / peak_amp_df['mean_peak_uv']

print(peak_amp_df[['label', 'global_peak_uv', 'mean_peak_uv', 'dominant_channel', 'focality_ratio']].head(10))
# Out:
#                  label  global_peak_uv  mean_peak_uv dominant_channel  \
# file_id
# S01      Non_Epileptic         80.0006     26.679520         E C4-Ref
# S02          Epileptic         74.6211     34.754084        E T10-Ref
# S03          Epileptic        120.9815     56.275544         E F4-Ref
# S04      Non_Epileptic         54.9922     34.278572         E F9-Ref
# S05          Epileptic        100.9846     54.235556         E F7-Ref
# S06      Non_Epileptic        280.9580     55.919144         E P8-Ref
# S07          Epileptic        106.9837     38.596616        E F10-Ref
# S08          Epileptic         83.9974     29.477904        E T10-Ref
# S09          Epileptic         96.9852     32.235500        E F10-Ref
# S10      Non_Epileptic         82.9873     40.238768         E T7-Ref
#
#          focality_ratio
# file_id
# S01            2.998577
# S02            2.147117
# S03            2.149806
# S04            1.604273
# S05            1.861963
# S06            5.024362
# ...

# %%
# summary statistics by group
summary_cols = ['global_peak_uv', 'mean_peak_uv', 'focality_ratio']
print(peak_amp_df.groupby('label')[summary_cols].describe().T)
# Out:
# label                  Epileptic  Non_Epileptic
# global_peak_uv count   54.000000      46.000000
#                mean   130.391750      93.624089
#                std     79.214717      69.765986
#                min     34.003100      35.001300
#                25%     80.247550      55.743700
#                50%    113.480150      71.493500
#                75%    139.992525      96.994050
#                max    465.985800     407.998500
# mean_peak_uv   count   54.000000      46.000000
#                mean    56.526894      38.418617
#                std     47.343356      24.558456
#                min     16.878352      13.960376
#                25%     34.272806      26.006483
#                50%     46.578194      31.218156
#                75%     57.509651      43.158511
#                max    324.529244     161.762732
# focality_ratio count   54.000000      46.000000
#                mean     2.477286       2.561686
#                std      0.604574       1.339750
# ...

# %%
# visualise distributions
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for ax, col in zip(axes, summary_cols):
    for label, group in peak_amp_df.groupby('label'):
        ax.hist(group[col], bins=15, alpha=0.5, label=label)
    ax.set_title(col)
    ax.set_xlabel(col)
    ax.set_ylabel('count')
    ax.legend()

plt.tight_layout()
plt.savefig('../figures/peak_amplitude_distributions.png', dpi=800, bbox_inches='tight')
plt.show()

# %%
# flag any files with unusually high global peak (potential artefact)
threshold = 200  # microvolts, well above typical EEG
outliers = peak_amp_df[peak_amp_df['global_peak_uv'] > threshold]
print(f"Files with global peak above {threshold} uV:")
print(outliers[['label', 'global_peak_uv', 'dominant_channel', 'focality_ratio']])
# Out:
# Files with global peak above 200 uV:
#                  label  global_peak_uv dominant_channel  focality_ratio
# file_id
# S06      Non_Epileptic        280.9580         E P8-Ref        5.024362
# S39          Epileptic        382.0350        E FP1-Ref        1.890082
# S44          Epileptic        465.9858        E FP2-Ref        1.435882
# S49      Non_Epileptic        407.9985         E Pz-Ref        8.901221
# S55          Epileptic        213.0195        E FP1-Ref        3.677758
# S74      Non_Epileptic        239.9927        E FP2-Ref        2.386752
# S84      Non_Epileptic        205.0188        E F10-Ref        1.267404
# S93          Epileptic        280.0256         E F3-Ref        2.435055
# S97          Epileptic        336.9486         E T8-Ref        3.023760

# %%
raws['S44'].plot(block=True) # epileptic
# Out:
# <MNEBrowseFigure size 1128x800 with 4 Axes>
# <MNEBrowseFigure size 1128x800 with 4 Axes>

# %%
raws['S49'].plot(block=True) # non epileptic
# Out:
# <MNEBrowseFigure size 1128x800 with 4 Axes>
# <MNEBrowseFigure size 1128x800 with 4 Axes>

# %%
# zoom in: show only 1 second either side of the transient
for fid in ['S44', 'S49']:
    raw = raws[fid]
    t_onset = [a['onset'] for a in raw.annotations if 'Annotation' in a['description']][0]
    raw.plot(start=t_onset - 1, duration=2, block=True, title=fid)
# Out:
# <MNEBrowseFigure size 1128x800 with 4 Axes>
# <MNEBrowseFigure size 1128x800 with 4 Axes>

# %%
peak_amp_df['high_amplitude_flag'] = peak_amp_df['global_peak_uv'] > 200
df['high_amplitude_flag'] = df['file_id'].map(peak_amp_df['high_amplitude_flag'])
df
# Out:
#    file_id sample_id          label  label_binary gender  age  sfreq_hz  \
# 0      S01        S1  Non_Epileptic             0      F   34     500.0
# 1      S02        S2      Epileptic             1      M   77     500.0
# 2      S03        S3      Epileptic             1      M   14     500.0
# 3      S04        S4  Non_Epileptic             0      M   12     500.0
# 4      S05        S5      Epileptic             1      M   46     500.0
# ..     ...       ...            ...           ...    ...  ...       ...
# 95     S95       S95  Non_Epileptic             0      F   25     500.0
# 96     S96       S96      Epileptic             1      F   14     500.0
# 97     S97       S97      Epileptic             1      F   30     500.0
# 98     S98       S98  Non_Epileptic             0      F   38     500.0
# 99     S99       S99  Non_Epileptic             0      F   37     500.0
#
#     duration_s  n_channels_total  n_eeg_channels  ...  annotation_status  \
# ...

# %% [markdown]
# ## Clear and unclear positives

# %%
CLEAR_POSITIVES = [1, 4, 6, 7, 8, 12, 17, 18, 22, 25, 28, 30, 43, 44, 45, 49,
                   52, 64, 66, 86, 96, 99]

UNCLEAR_POSITIVES = [2, 10, 13, 15, 20, 26, 29, 32, 35, 36, 38, 40, 41, 46, 51,
                     54, 55, 57, 59, 61, 68, 69, 71, 74, 75, 78, 81, 85, 89,
                     92, 93, 95]

NEGATIVES = [0, 3, 5, 9, 11, 14, 16, 19, 21, 23, 24, 27, 31, 33, 34, 37, 39,
             42, 47, 48, 50, 53, 56, 58, 60, 62, 63, 65, 67, 70, 72, 73, 76,
             77, 79, 80, 82, 83, 84, 87, 88, 90, 91, 94, 97, 98]

def index_to_file_id(idx):
    return 'S' + str(idx + 1).zfill(2)

df['certainty'] = 'unknown'
df.loc[df['file_id'].isin([index_to_file_id(i) for i in CLEAR_POSITIVES]), 'certainty'] = 'clear_positive'
df.loc[df['file_id'].isin([index_to_file_id(i) for i in UNCLEAR_POSITIVES]), 'certainty'] = 'unclear_positive'
df.loc[df['file_id'].isin([index_to_file_id(i) for i in NEGATIVES]), 'certainty'] = 'negative'

print(df['certainty'].value_counts())
print(df[df['certainty'] == 'unknown'])
# Out:
# certainty
# negative            46
# unclear_positive    32
# clear_positive      22
# Name: count, dtype: int64
# Empty DataFrame
# Columns: [file_id, sample_id, label, label_binary, gender, age, sfreq_hz, duration_s, n_channels_total, n_eeg_channels, n_annotations_total, n_transient_markers, annotation_status, transient_onset_s, pre_transient_s, post_transient_s, frac_position, all_annotation_labels, load_error, reduced_channels, has_hawk_log, high_amplitude_flag, certainty]
# Index: []
#
# [0 rows x 23 columns]

# %%
df[['file_id', 'certainty']]
# Out:
#    file_id         certainty
# 0      S01          negative
# 1      S02    clear_positive
# 2      S03  unclear_positive
# 3      S04          negative
# 4      S05    clear_positive
# ..     ...               ...
# 95     S95          negative
# 96     S96  unclear_positive
# 97     S97    clear_positive
# 98     S98          negative
# 99     S99          negative
#
# [100 rows x 2 columns]

# %%
print(df.columns.tolist())
# Out:
# ['file_id', 'sample_id', 'label', 'label_binary', 'gender', 'age', 'sfreq_hz', 'duration_s', 'n_channels_total', 'n_eeg_channels', 'n_annotations_total', 'n_transient_markers', 'annotation_status', 'transient_onset_s', 'pre_transient_s', 'post_transient_s', 'frac_position', 'all_annotation_labels', 'load_error', 'reduced_channels', 'has_hawk_log', 'high_amplitude_flag', 'certainty']

# %%
df.to_csv('../Kural_Dataset/eeg_summary.csv', index=False)

# %%
df
# Out:
#    file_id sample_id          label  label_binary gender  age  sfreq_hz  \
# 0      S01        S1  Non_Epileptic             0      F   34     500.0
# 1      S02        S2      Epileptic             1      M   77     500.0
# 2      S03        S3      Epileptic             1      M   14     500.0
# 3      S04        S4  Non_Epileptic             0      M   12     500.0
# 4      S05        S5      Epileptic             1      M   46     500.0
# ..     ...       ...            ...           ...    ...  ...       ...
# 95     S95       S95  Non_Epileptic             0      F   25     500.0
# 96     S96       S96      Epileptic             1      F   14     500.0
# 97     S97       S97      Epileptic             1      F   30     500.0
# 98     S98       S98  Non_Epileptic             0      F   38     500.0
# 99     S99       S99  Non_Epileptic             0      F   37     500.0
#
#     duration_s  n_channels_total  n_eeg_channels  ...  transient_onset_s  \
# ...

# %% [markdown]
# # Basis comparison: B-spline vs Fourier
#
# **Motivation (supervisor).** EEG can be viewed as a sum of periodic components, which suggests a
# Fourier basis. But the annotated events are *localised* sharp transients (spikes 20-70 ms, sharp
# waves 70-200 ms) - point-like features that a global periodic basis may fit poorly (Gibbs ringing,
# energy smeared across many harmonics). Local B-splines are the opposite: good at localised features,
# weak on long-range periodicity. Which is better for *this* signal is an empirical question.
#
# **Two separate questions, which use fit error in opposite directions:**
#
# 1. **Basis as smoother** (what the classifier currently uses). We want *low* reconstruction error on
#    the transient, because the smoothed curve feeds registration + FPCA. Better basis = lower error on
#    the transient.
# 2. **Fit error as a feature** (new idea). Fit a Fourier basis that models the *background rhythm*; the
#    residual (raw - fit) is what the periodic model cannot explain = the transient itself. Here we
#    *want* high, informative error - large residual at the marker could flag an epileptic spike. This is
#    a non-periodicity / spikiness feature, different from amplitude and phase.
#
# **What this section shows** (all on the max-peak-to-peak EEG channel per recording, EKG dropped, on a
# 2 s window centred on the marker - the same channel the classifier sees):
#
# - **Overlay fits** - raw vs spline vs Fourier at matched DoF, for one negative / unclear-positive /
#   clear-positive example, full window and zoomed on the transient. Look for Gibbs ringing.
# - **Residual vs time** - where each basis fails. Splines should give a roughly flat residual; Fourier
#   should spike at the transient with ringing sidelobes. This is the visual basis of the feature idea.
# - **Error vs degrees of freedom** - reconstruction error (relative L2) in the transient window and in
#   the background window, swept over DoF, averaged across recordings. The honest full picture: how the
#   two bases trade off, and whether Fourier only matches splines on the transient by spending many terms.
# - **Transient vs background error** - the same comparison as four summary bars at matched DoF.
# - **Coefficient concentration** - cumulative reconstruction energy captured vs number of coefficients
#   (sorted by magnitude). Shows whether one basis represents the curve more sparsely than the other.
# - **Per-class residual energy** - Fourier residual energy in the transient window, split by certainty,
#   plus a quick in-sample single-feature separability (AUC) vs the peak-to-peak amplitude - a cheap
#   viability check for the fit-error feature before committing any nested-CV time to it.
#
# **Methodological notes.** (i) We fit on the *full 2 s window* and measure error in the transient
# sub-window - this mirrors how the smoother is actually used (it fits the whole window; we care whether
# the transient survives). (ii) DoF matching is not exact for Fourier: skfda's `FourierBasis` needs an
# odd term count (constant + sin/cos pairs), so "match 30" means Fourier = 31.

# %%
# --- Basis comparison setup: reuse raws already loaded above ---
import numpy as np
from sklearn.metrics import roc_auc_score
from skfda import FDataGrid
from skfda.preprocessing.smoothing import BasisSmoother
from skfda.representation.basis import BSplineBasis, FourierBasis, FDataBasis

SFREQ   = 500.0
HALF_S  = 1.0                       # +/-1 s -> 2 s window
N_HALF  = int(HALF_S * SFREQ)       # 500
N_SAMP  = 2 * N_HALF                # 1000
PEAK_HW = int(0.1 * SFREQ)          # +/-0.1 s for channel selection
t       = (np.arange(N_SAMP) - N_HALF) / SFREQ
DR      = (t[0], t[-1])
MASK_T  = np.abs(t) <= 0.1          # transient window
MASK_BG = np.abs(t) >= 0.2          # background (0.1-0.2 s left as a guard band)

DOF_MATCH = 30                      # spline n_basis the classifier uses
DOF_FOUR  = 31                      # matched odd Fourier term count

# certainty + onset from the classification manifest (keyed by file_id, same keys as raws)
summ = pd.read_csv('../Kural_Dataset/eeg_summary.csv')
summ = summ[summ['load_error'].isna() & (summ['annotation_status'] == 'ok')].set_index('file_id')

def make_basis(kind, dof):
    if kind == 'spline':
        return BSplineBasis(domain_range=DR, n_basis=dof, order=4)
    dof = dof if dof % 2 == 1 else dof + 1      # Fourier needs odd
    return FourierBasis(domain_range=DR, n_basis=dof)

def smooth_grid(curve, kind, dof):
    fdg = FDataGrid(curve[None, :], t)
    return BasisSmoother(make_basis(kind, dof), return_basis=False).fit_transform(fdg).data_matrix[0, :, 0]

def rel_err(curve, fit, mask):
    return np.linalg.norm((curve - fit)[mask]) / np.linalg.norm(curve[mask])

def get_curve(file_id):
    """Max peak-to-peak EEG channel (EKG dropped), 2 s window centred on marker, in uV."""
    raw   = raws[file_id]
    onset = summ.loc[file_id, 'transient_onset_s']
    eeg   = [c for c in raw.ch_names if c.startswith('E ')]
    idx   = [raw.ch_names.index(c) for c in eeg]
    s0    = int(round((onset - HALF_S) * SFREQ))
    data  = raw.get_data(picks=idx)[:, s0:s0 + N_SAMP] * 1e6
    ch    = np.argmax(np.ptp(data[:, N_HALF - PEAK_HW:N_HALF + PEAK_HW], axis=1))
    return data[ch]

# keep recordings with a full 2 s window and clean load
kept = [f for f in summ.index if f in raws
        and summ.loc[f, 'transient_onset_s'] >= HALF_S
        and summ.loc[f, 'transient_onset_s'] + HALF_S <= summ.loc[f, 'duration_s']]
curves = {f: get_curve(f) for f in kept}

# one representative per certainty = median peak-to-peak within the group
CERT_ORDER = ['negative', 'unclear_positive', 'clear_positive']
examples = {}
for c in CERT_ORDER:
    grp = sorted([f for f in kept if summ.loc[f, 'certainty'] == c],
                 key=lambda f: np.ptp(curves[f][MASK_T]))
    examples[c] = grp[len(grp) // 2]

print(f'Kept {len(kept)}/{len(summ)} recordings with a full +/-{HALF_S:.0f}s window')
for c in CERT_ORDER:
    print(f'  {c:16s} example: {examples[c]}')
# Out:
# Kept 100/100 recordings with a full +/-1s window
#   negative         example: S63
#   unclear_positive example: S86
#   clear_positive   example: S87

# %%
# --- Overlay fits: raw vs spline vs Fourier at matched DoF (full window + zoom) ---
fig, axes = plt.subplots(len(CERT_ORDER), 2, figsize=(14, 10))
for r, c in enumerate(CERT_ORDER):
    curve = curves[examples[c]]
    fit_s = smooth_grid(curve, 'spline',  DOF_MATCH)
    fit_f = smooth_grid(curve, 'fourier', DOF_MATCH)
    for k, (ax, xlim) in enumerate(zip(axes[r], [(t[0], t[-1]), (-0.15, 0.15)])):
        ax.plot(t, curve, color='0.6', lw=0.8, label='raw')
        ax.plot(t, fit_s, color='C0', lw=1.6, label=f'spline (nb={DOF_MATCH})')
        ax.plot(t, fit_f, color='C1', lw=1.6, label=f'fourier (nb={DOF_FOUR})')
        ax.axvline(0, color='k', ls='--', lw=0.7)
        ax.set_xlim(xlim); ax.set_xlabel('time (s)')
        if k == 0:
            ax.set_ylabel(f'{c}\n({examples[c]})  uV')
        ax.set_title('full window' if k == 0 else 'zoom on transient')
        if r == 0 and k == 0:
            ax.legend(fontsize=8)
plt.suptitle('Reconstruction at matched degrees of freedom', y=1.005)
plt.savefig('../figures/basis_reconstruction.png', dpi=800, bbox_inches='tight')
plt.show()

# %%
# --- Residual vs time: where each basis fails ---
fig, axes = plt.subplots(len(CERT_ORDER), 1, figsize=(13, 9), sharex=True)
for ax, c in zip(axes, CERT_ORDER):
    curve = curves[examples[c]]
    res_s = curve - smooth_grid(curve, 'spline',  DOF_MATCH)
    res_f = curve - smooth_grid(curve, 'fourier', DOF_MATCH)
    ax.axvspan(-0.1, 0.1, color='0.9', label='transient window')
    ax.axhline(0, color='k', lw=0.6)
    ax.plot(t, res_s, color='C0', lw=1.0, label='spline residual')
    ax.plot(t, res_f, color='C1', lw=1.0, label='fourier residual')
    ax.set_ylabel(f'{c}\nresidual uV')
    if c == CERT_ORDER[0]:
        ax.legend(fontsize=8, ncol=3, loc='upper right')
axes[-1].set_xlabel('time (s)')
plt.suptitle('Residual (raw - fit) at matched DoF -- localisation of error', y=1.005)
plt.savefig('../figures/basis_residuals.png', dpi=800, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Frequency response — why matched DoF is fair, and what nb=30 actually is
#
# Before comparing errors, establish what "same degrees of freedom" *means*. Fit a pure sinusoid of
# known frequency with each basis and measure how much of its amplitude survives. Retention is measured
# on the **interior only** (|t| < 0.5 s) so that spline boundary ringing is not mistaken for passband.
#
# The result (below): **both bases act as low-pass filters with an effective cutoff at ~ `n_basis/(2T)`**
# (T = 2 s window). So equal DoF ≈ equal cutoff frequency ≈ equal effective resolution — that is what
# makes the matched-DoF comparison fair. The two bases differ not in *how much* resolution they have but
# in *how they spend it*: splines locally, Fourier globally.
#
# It also makes the classifier's choice legible. `nb=30` -> cutoff ≈ **7.5 Hz**. In clinical terms a
# sharp wave (70-200 ms) sits around 2.5-7 Hz and is (barely) representable; a spike (20-70 ms) needs
# ~7-25 Hz and is **removed**. Resolving a 20 ms spike would need `n_basis ≈ 2T·25 ≈ 100`, above the
# grid ceiling of 80. So the nested CV picking `nb=30` means it prefers a representation that keeps the
# coarse sub-8 Hz envelope of the transient and discards its fine spike morphology.

# %%
# --- Frequency response: amplitude retained vs input frequency (interior RMS ratio) ---
FR_FREQS = np.arange(1, 41, 0.5)
INTERIOR = np.abs(t) < 0.5
TW       = t[-1] - t[0]              # window length ~2 s; cutoff ~ n_basis/(2*TW)

def retention(freq, kind, dof):
    s   = np.sin(2 * np.pi * freq * t)
    fit = smooth_grid(s, kind, dof)
    return np.sqrt(np.mean(fit[INTERIOR] ** 2)) / np.sqrt(np.mean(s[INTERIOR] ** 2))

fig, ax = plt.subplots(figsize=(9, 5))
LS = {DOF_MATCH: '-', 80: '--'}
for dof in (DOF_MATCH, 80):
    for kind, col in [('spline', 'C0'), ('fourier', 'C1')]:
        r = [retention(f, kind, dof) for f in FR_FREQS]
        ax.plot(FR_FREQS, r, color=col, ls=LS[dof], label=f'{kind} nb={dof}')
    ax.axvline(dof / (2 * TW), color='0.5', ls=':', lw=0.8)          # predicted cutoff
ax.axvspan(2.5, 7, color='tab:green', alpha=0.07)
ax.axvspan(7, 25, color='tab:red',   alpha=0.07)
ax.text(4.75, 1.10, 'sharp wave', ha='center', fontsize=8, color='tab:green')
ax.text(16,   1.10, 'spike',      ha='center', fontsize=8, color='tab:red')
ax.axhline(0.5, color='k', lw=0.5, ls=':')
ax.set_xlabel('input frequency (Hz)')
ax.set_ylabel('amplitude retained (interior RMS ratio)')
ax.set_title('Basis frequency response -- both are low-pass with cutoff ~ n_basis/(2T)')
ax.set_ylim(0, 1.2); ax.set_xlim(0, 40); ax.legend(fontsize=8)
plt.tight_layout(); plt.savefig('../figures/basis_frequency_response.png', dpi=800, bbox_inches='tight')
plt.show()

# %%
# --- Reconstruction error vs degrees of freedom (averaged over recordings) ---
DOFS = [11, 15, 21, 31, 41, 61, 81]
err = {(kind, reg): np.full((len(kept), len(DOFS)), np.nan)
       for kind in ('spline', 'fourier') for reg in ('transient', 'background')}
for j, dof in enumerate(DOFS):
    for i, f in enumerate(kept):
        curve = curves[f]
        for kind in ('spline', 'fourier'):
            fit = smooth_grid(curve, kind, dof)
            err[(kind, 'transient')][i, j]  = rel_err(curve, fit, MASK_T)
            err[(kind, 'background')][i, j] = rel_err(curve, fit, MASK_BG)

TW = t[-1] - t[0]                      # window length ~2 s; cutoff ~ DoF/(2*TW)
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
for ax, reg in zip(axes, ('transient', 'background')):
    for kind, col in [('spline', 'C0'), ('fourier', 'C1')]:
        a = err[(kind, reg)]
        med, lo, hi = np.median(a, 0), np.percentile(a, 25, 0), np.percentile(a, 75, 0)
        ax.plot(DOFS, med, color=col, marker='o', label=kind)
        ax.fill_between(DOFS, lo, hi, color=col, alpha=0.15)
    ax.axvline(DOF_MATCH, color='k', ls=':', lw=0.8, label=f'classifier DoF ({DOF_MATCH})')
    ax.set_xlabel('degrees of freedom'); ax.set_ylabel('relative L2 error')
    ax.set_title(f'{reg} window'); ax.legend(fontsize=8)
    secax = ax.secondary_xaxis('top', functions=(lambda d: d / (2 * TW),
                                                 lambda hz: hz * 2 * TW))
    secax.set_xlabel('approx. cutoff frequency (Hz)')
plt.suptitle('Reconstruction error vs DoF (median, IQR band across recordings)', y=1.10)
plt.tight_layout(); plt.savefig('../figures/basis_reconstruction_error.png', dpi=800, bbox_inches='tight')
plt.show()

# %%
# --- Transient vs background error at matched DoF (summary bars) ---
means = {(kind, reg): np.mean([rel_err(curves[f], smooth_grid(curves[f], kind, DOF_MATCH),
                                        MASK_T if reg == 'transient' else MASK_BG) for f in kept])
         for kind in ('spline', 'fourier') for reg in ('transient', 'background')}
fig, ax = plt.subplots(figsize=(7, 4.5))
x = np.arange(2); w = 0.35
for k, (kind, col) in enumerate([('spline', 'C0'), ('fourier', 'C1')]):
    ax.bar(x + (k - 0.5) * w, [means[(kind, 'transient')], means[(kind, 'background')]],
           w, color=col, label=kind)
ax.set_xticks(x); ax.set_xticklabels(['transient', 'background'])
ax.set_ylabel('mean relative L2 error')
ax.set_title(f'Error by region at matched DoF (nb={DOF_MATCH})'); ax.legend()
plt.tight_layout(); plt.savefig('../figures/basis_error_by_region.png', dpi=800, bbox_inches='tight')
plt.show()

# %%
# --- Coefficient concentration: cumulative reconstruction energy vs # coefficients ---
DOF_CONC = 61
def captured_curve(curve, kind):
    fdg  = FDataGrid(curve[None, :], t)
    fb   = BasisSmoother(make_basis(kind, DOF_CONC), return_basis=True).fit_transform(fdg)
    coefs = fb.coefficients[0]
    full  = fb.to_grid(t).data_matrix[0, :, 0]
    order = np.argsort(np.abs(coefs))[::-1]
    n2    = np.sum(full ** 2)
    out = []
    for k in range(1, len(coefs) + 1):
        c = np.zeros_like(coefs); c[order[:k]] = coefs[order[:k]]
        rec = FDataBasis(fb.basis, c[None, :]).to_grid(t).data_matrix[0, :, 0]
        out.append(1 - np.sum((full - rec) ** 2) / n2)
    return np.array(out)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
for ax, c in zip(axes, ['clear_positive', 'negative']):
    curve = curves[examples[c]]
    for kind, col in [('spline', 'C0'), ('fourier', 'C1')]:
        cap = captured_curve(curve, kind)
        ax.plot(np.arange(1, len(cap) + 1), cap, color=col, label=kind)
    ax.axhline(0.95, color='k', ls=':', lw=0.8)
    ax.set_xlabel('# coefficients (sorted by magnitude)')
    ax.set_ylabel('fraction of reconstruction energy')
    ax.set_title(f'{c}  ({examples[c]})'); ax.legend(fontsize=8)
plt.suptitle(f'Coefficient concentration (DoF={DOF_CONC})', y=1.02)
plt.tight_layout(); plt.savefig('../figures/basis_coefficient_concentration.png', dpi=800, bbox_inches='tight')
plt.show()

# %%
# --- Fit-error-as-feature viability: Fourier residual energy in the transient window ---
resid_e = np.array([np.mean((curves[f] - smooth_grid(curves[f], 'fourier', DOF_MATCH))[MASK_T] ** 2)
                    for f in kept])
p2p     = np.array([np.ptp(curves[f][MASK_T]) for f in kept])
ylab    = summ.loc[kept, 'label_binary'].to_numpy()
certs   = summ.loc[kept, 'certainty'].to_numpy()

fig, ax = plt.subplots(figsize=(7, 4.5))
ax.boxplot([resid_e[certs == c] for c in CERT_ORDER], labels=CERT_ORDER, showfliers=False)
ax.set_ylabel('Fourier residual energy in transient window (uV^2)')
ax.set_title('Residual energy by certainty group')
plt.tight_layout(); plt.savefig('../figures/basis_residual_energy_by_group.png', dpi=800, bbox_inches='tight')
plt.show()

print('In-sample single-feature separability (AUC vs label_binary, NOT cross-validated):')
print(f'  Fourier residual energy : {roc_auc_score(ylab, resid_e):.3f}')
print(f'  peak-to-peak amplitude  : {roc_auc_score(ylab, p2p):.3f}')
print('  (rough sanity check only -- the pipeline peak-to-peak baseline was 0.741 under CV)')
# Out:
# /var/folders/qq/plc0t9_900x48dmp2lkz0k3m0000gn/T/ipykernel_33090/385581349.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot([resid_e[certs == c] for c in CERT_ORDER], labels=CERT_ORDER, showfliers=False)
# In-sample single-feature separability (AUC vs label_binary, NOT cross-validated):
#   Fourier residual energy : 0.571
#   peak-to-peak amplitude  : 0.758
#   (rough sanity check only -- the pipeline peak-to-peak baseline was 0.741 under CV)
